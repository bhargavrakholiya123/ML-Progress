# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavrakholiya123/ML-Progress/blob/main/GenAI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import userdata
API = userdata.get('API_KEY')

# %%
import google.generativeai as genai
genai.configure(api_key="AIzaSyD5ybGIhupDkdjxE4Wkb1fX7ovC6YehHTw")

# %%
model = genai.GenerativeModel("gemini-2.5-flash")
# Out:
# Okay, perfect! Glad to hear it. How can I help you?

# %%
def explain_code(code):
  prompt = f""" you are proffesional coder and have 10 years of experience in teaching computer science , your task is to explain code most easiest
  and most simplest way
  - make it short and simple
  - give real world example
  - make coding interesting

  code : {code}

  """

  response = model.generate_content(prompt)
  return response.text

# %%
print(explain_code("""
def add(a, b):
    return a + b
"""))
# Out:
# Alright future coding superstar, let's unlock this tiny but mighty piece of code!
#
# ```python
# def add(a, b):
#     return a + b
# ```
#
# ### The Super Simple Scoop:
# This is like building your own mini-calculator! You give it two numbers, and it instantly spits out their sum.
#
# ### How it Works (Your Personal Robot Chef):
#
# 1.  **`def add(a, b):`**: You're telling your robot, "Hey, I'm creating a new task called 'add'. It needs two ingredients from me to start (let's call them `a` and `b`)."
# 2.  **`return a + b`**: Your robot performs the addition (`a` plus `b`) and then **gives you back** the final answer.
#
# ### Real-World Magic:
# Imagine you're at a grocery store. When the cashier scans your items, this `add` function is working hard behind the scenes! Item 1's price (`a`) + Item 2's price (`b`) = your running total. It's how virtually every calculator and checkout system works!
#
# ### Why it's AWESOME:
# ...
