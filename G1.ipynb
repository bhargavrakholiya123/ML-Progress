# %%
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

import numpy as np

# %%
x = [10,20,30,40,50]
x = np.array(x).reshape(-1, 1)
y = [800,700,600,500,400]
y = np.array(y)

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=.2,random_state=42)

# %%
model1 = LinearRegression()

# %%
model1.fit(xTrain,yTrain)
# Out:
# LinearRegression()

# %%
predictions = model1.predict(x_test)

# %%
print(confusion_matrix(y_test, predictions))
# Out:
# [[1]]
# C:\Users\as\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:407: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(

# %%
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#          700       1.00      1.00      1.00         1
#
#     accuracy                           1.00         1
#    macro avg       1.00      1.00      1.00         1
# weighted avg       1.00      1.00      1.00         1

# %%
from sklearn.metrics import classification_report, confusion_matrix

y_true = [0, 1, 0, 1, 0, 1]  # Actual answers
y_pred = [0, 0, 0, 1, 1, 1]  # Model guesses

print("--- The Report Card ---")
print(classification_report(y_true, y_pred))

print("\n--- The Raw Counts ---")
print(confusion_matrix(y_true, y_pred))
# Out:
# --- The Report Card ---
#               precision    recall  f1-score   support
#
#            0       0.67      0.67      0.67         3
#            1       0.67      0.67      0.67         3
#
#     accuracy                           0.67         6
#    macro avg       0.67      0.67      0.67         6
# weighted avg       0.67      0.67      0.67         6
#
#
# --- The Raw Counts ---
# [[2 1]
#  [1 2]]

# %%
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier, plot_tree
import matplotlib.pyplot as plt

# 1. Load Data
data = load_iris()
X = data.data
y = data.target

# 2. Create the Model
# max_depth=2 limits the tree size so it doesn't get too crazy
model = DecisionTreeClassifier(max_depth=2)

# 3. Train it
model.fit(X, y)

# 4. DRAW the tree! (The cool part)
plt.figure(figsize=(10, 8))
plot_tree(model, feature_names=data.feature_names, filled=True)
plt.show()
